# %% [markdown]
# # Nullstellen

# %% [markdown]
# ## Arbeitsblatt zur Einarbeitung

# %% [markdown]
# Dieses Arbeitsblatt soll durchgearbeitet werden, bevor mit der Vertiefung begonnen wird. Die Lösungen werden zwischen Freitag Abend und Montag Morgen hochgeladen.
#
# Hier lernst du zwei Verfahren zur Berechnung von Nullstellen von Funktionen kennen. Das Ziel ist, deren Funktionsweise kennenzulernen, indem du sie selbst rudimentär implementierst. Details und Verfeinerungen folgen in der Vertiefung.

# %% [markdown]
# ### Bisektionsverfahren

# %% [markdown]
# Das einfachste Nullstellenverfahren beruht auf dem [Zwischenwertsatz](https://de.wikipedia.org/wiki/Zwischenwertsatz) der Analysis. Dieser besagt, dass eine stetige Funktion auf einem Intervall $[a,b]$ sicher alle Werte zwischen $f(a)$ und $f(b)$ annimmt. Haben $f(a)$ und $f(b)$ unterschiedliche Vorzeichen, so muss also eine Nullstelle dazwischen liegen. Dies nutzt man, um die Nullstelle durch wiederholtes Halbieren des Intervalls einzugrenzen.
#
# Eine kurze Beschreibungen des Algorithmus und die folgende Animation findest du hier: ["Das Bisektionsverfahren", Numerik I - Wikiversity](https://de.wikiversity.org/wiki/Kurs:Numerik_I/Nullstellenverfahren#Das_Bisektionsverfahren).
#
# > ![Animation des Bisektionsverfahrens](Bisektion_Ani.gif)
# >
# > Pfeifer, R. (2005, Mai 22). *Bisektion Ani* [GIF]. Wikimedia Commons (https://commons.wikimedia.org/wiki/File:Bisektion_Ani.gif). [CC BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0/).
#
# Baue ein grundlegendes Verständnis auf, indem du mindestens eines der folgenden Videos schaust:
# - ["Bisektionsverfahren, fortgesetzte Bisektion, Intervallhalbierung" - MathePeter](https://www.youtube.com/watch?v=SctNmizHzXk)
# - ["Bisektion, Bisektionsverfahren, Intervallhalbierung, Gleichungen lösen" - Daniel Jung](https://www.youtube.com/watch?v=poOt34st_ao)

# %% [markdown]
# ### Newton-Verfahren

# %% [markdown]
# Das Newton-Verfahren nutzt die Linearisierung der Funktion, deren Nullstelle zu berechnen ist. Ausgehend von einer Schätzung der Nullstelle liefert die Nullstelle der Linearisierung eine neue Näherung der gesuchten Nullstelle. Diese Iteration konvergiert in der Regel schnell.
#
# Eine kurze Beschreibungen des Algorithmus und die folgende Animation findest du hier: ["Das Newton-Verfahren", Numerik I - Wikiversity](https://de.wikiversity.org/wiki/Kurs:Numerik_I/Nullstellenverfahren#Newton-Verfahren_f%C3%BCr_Nullstellen).
#
# > ![Animation des Newton-Verfahrens](NewtonIteration_Ani.gif)
# >
# > Pfeifer, R. (2005, April 9). *NewtonIteration Ani* [GIF]. Wikimedia Commons (https://commons.wikimedia.org/wiki/File:NewtonIteration_Ani.gif). [CC BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0/).
#
# Schaue mindestens eines der folgenden Videos an:
# - ["Newton-Verfahren (Nullstellen bestimmen)" - Mathe-simpleclub](https://www.youtube.com/watch?v=xGemDmrCqEk)
# - ["Newton Verfahren" - MathePeter](https://www.youtube.com/watch?v=JdMVcHUfAs0)
# - [Playlist: "Newton-Verfahren, Gleichungen lösen, Newton-Raphson-Verfahren" - Daniel Jung](https://www.youtube.com/playlist?list=PLLTAHuUj-zHgXrIFYSt6cjADaHOg8QWjy)

# %% [markdown]
# ### Gleichungen als Nullstellenprobleme

# %% [markdown]
# Jegliche Gleichungen, in denen keine Ableitungen oder Integrationen vorkommen, können als Nullstellen von Funktionen umgeschrieben werden. Man nimmt einfach alle Terme auf die linke Seite der Gleichung und erhält so eine Nullstellengleichung einer Funktion.
#
# **Beispiel:**
#
# $$
# x^2 -5 = 2x + \sin(x) \quad \Leftrightarrow \quad f(x) = x^2 - 2x - 5 - \sin(x) \stackrel{!}{=} 0
# $$
#
# **Bemerkungen:**
#
# - Das Finden von Nullstellen wird im Englischen als *root finding* bezeichnet.
# - *Fixpunkte* einer Funktion nennt man Punkte $x$, für die $f(x) = x$ gilt.
#   - Fixpunkte sind also Nullstellen der Funktion $g(x) = f(x) - x$.

# %% [markdown]
# ## Arbeitsauftrag

# %% [markdown]
# ### Aufgabe 1

# %% [markdown]
# Wofür brauchen wir die Nullstellen einer Funktion?

# %% [markdown]
# ### Aufgabe 2

# %% [markdown]
# **Entscheide dich für die restlichen Aufgaben für eines der beiden Verfahren: Bisektion oder Newton.** (Das Bisektionsverfahren ist etwas schwieriger zu implementieren.)
#
# Schreibe das grundsätzliche Vorgehen (Ablauf des Algorithmus) für die Berechnung von Nullstellen anhand des gewählten Verfahrens auf.

# %% [markdown]
# ### Aufgabe 3

# %% [markdown]
# Wir betrachten die Funktion
#
# $$
#     f(x) = 2 - x^2
# $$
#
# Sie hat zwei Nullstellen: $x_\pm = \pm\sqrt{2}$.
#
# Die irrationale Zahl $\sqrt{2}$ kann nicht direkt von Hand berechnet werden. Daher soll sie hier als Nullstelle der Funktion $f(x)$ näherungsweise numerisch berechnet werden.

# %% [markdown]
# **a)**
#
# - Definiere die Funktion $f(x)=2-x^2$ als Python Funktion `f(x)`.
# - Stelle $f(x)$ mithilfe von Matplotlib im Bereich $x\in[-2,2]$ grafisch dar.
# - Stelle zusätzlich die beiden Nullstellen $\pm\sqrt{2}$ als rote Punkte dar.
# - Füge Achsenbeschriftungen, eine Legende und ein Gitternetz (Grid) hinzu.

# %% [markdown]
# **b)** Wähle ein geeignetes Start-Intervall $[a_0,b_0]$ für das Bisektionsverfahren bzw. einen geeigneten Startwert $x_0$ für das Newton-Verfahren, abhängig von der in Aufgabe 2 gewählten Methode. Ziel ist, die positive $\sqrt{2}$ als Nullstelle zu bestimmen.

# %% [markdown]
# ### Aufgabe 4

# %% [markdown]
# Berechne mit Excel die Näherung der Nullstelle nach 2 Iterationsschritten des gewählten Verfahrens, also $[a_2,b_2]$ bzw. $x_2$. Schreibe das Resultat hier auf:

# %% [markdown]
# ### Aufgabe 5

# %% [markdown]
# Schreibe eine Funktion in Python, die das gewählte Verfahren implementiert.
#
# - *Inputs:*
#   - Bisektion: Funktion `f`, Start-Intervall `a0`, `b0` und Anzahl Iterationsschritte `n`
#   - Newton: Funktion `f`, deren Ableitung `fprime`, Startwert `x0` und Anzahl Iterationsschritte `n`
# - *Output:* $x$-Wert der Nullstelle nach der Anzahl Schritte. (Bei Bisektion den Mittelpunkt des Intervalls zurückgeben.)
# - *Option:* Es kann auch noch der Funktionswert an der gefundenen Stelle als Qualitätsindikator ausgegeben werden.
#
# Teste deine Funktion, indem Du mit den Resultaten aus Aufgabe 4 und `x_wolfram` vergleichst.

# %% [markdown]
# ### Aufgabe 6

# %% [markdown]
# Experimentiere mit deiner Lösung aus Aufgabe 5 oder dem Excel-Sheet aus Aufgabe 4, indem du die Anzahl Iterationsschritte erhöhst und den Startwert veränderst. Findest du auch die negative Nullstelle bei $x=-\sqrt{2}\,$?
#
# Notiere deine Beobachtungen.

# %%
# Zunehmende Anzahl Iterationen

# %%
# Negative Nullstelle

# %% [markdown]
# Beobachtungen:
#
# ...
